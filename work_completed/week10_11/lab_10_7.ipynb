# %% [markdown]
# Import and call here:

# %%
import lab_10_4 as album_directory

album_dictionary_1 = album_directory.make_album('True Pirate', 'Wolves of the Sea')
album_dictionary_2 = album_directory.make_album('Adrian Von Ziegler', 'Celtic Forest', 12)
album_dictionary_3 = album_directory.make_album('Casting Spells', 'Whimsical Eve', 8)
album_dictionary_4 = album_directory.make_album('Casting Spells', 'Majestic Mountain', 12)

album_collection = [album_dictionary_1, album_dictionary_2, album_dictionary_3, album_dictionary_4]

for album in album_collection:
    print(album)
# Out:
# {'artist': 'True Pirate', 'album': 'Wolves of the Sea'}
# {'artist': 'Adrian Von Ziegler', 'album': 'Celtic Forest', 'tracks': 12}
# {'artist': 'Casting Spells', 'album': 'Whimsical Eve', 'tracks': 8}
# {'artist': 'Casting Spells', 'album': 'Majestic Mountain', 'tracks': 12}
